# %% [markdown]
# # 1. Inicio de Sesión sobre SageMaker

# %%
#Utilitario para construir modelos de Machine Learning y Deep Learning
import sagemaker

#Importamos el utilitario para definir el entrenador del algoritmo
from sagemaker.estimator import Estimator

#Librería para manipular los servicios de AWS
import boto3

#Iniciamos sesión en el servicio de SageMaker
sesion = sagemaker.Session()

#Obtenemos la ejecución en donde estamos trabajando
region = sesion.boto_region_name

#Verificamos
print(region)

#Obtenemos el rol de ejecución de SageMaker
#El rol de ejecución permite a SageMaker usar otros servicios de AWS
rol = sagemaker.get_execution_role()
# Out:
# us-east-1

# %% [markdown]
# # 2. Lectura de archivos

# %%
#Utilitario para leer archivos de datos
from sagemaker.inputs import TrainingInput

#Bucket en donde se encuentran los archivos
#IMPORTANTE: REEMPLAZAR "XXX" POR TUS INICIALES
bucket = "datasetsbdajac"

#Lectura de datos de entrenamiento
dataTrain = TrainingInput(
    f"s3://{bucket}/data/bodyperformance_dataset_validacion_cruzada/vc3/train", #Ruta del archivo
    content_type = "text/csv", #Formato del archivo
    distribution = "FullyReplicated", #El archivo será copiado en todos los servidores
    s3_data_type = "S3Prefix", #Desde donde se lee el archivo (S3)
    input_mode = "File", #Los registros se encuentran dentro de archivos
    record_wrapping = "None" #Envoltorio de optimización
)

#Lectura de datos de validación
dataTest = TrainingInput(
    f"s3://{bucket}/data/bodyperformance_dataset_validacion_cruzada/vc3/test", #Ruta del archivo
    content_type = "text/csv", #Formato del archivo
    distribution = "FullyReplicated", #El archivo será copiado en todos los servidores
    s3_data_type = "S3Prefix", #Desde donde se lee el archivo (S3)
    input_mode = "File", #Los registros se encuentran dentro de archivos
    record_wrapping = "None" #Envoltorio de optimización
)

# %% [markdown]
# # 3. Configuración del Algoritmo

# %%
#Importamos el utilitario para definir el entrenador del algoritmo
from sagemaker.estimator import Estimator

#Definimos el entrenador del algoritmo
entrenador = Estimator(
    image_uri = sagemaker.image_uris.retrieve("xgboost", region, version = "latest"), #Descargamos la implementación del algoritmo desde la región donde trabajamos
    role = rol, #Rol que ejecuta servicios sobre AWS
    instance_count = 1, #Cantidad de servidores de entrenamiento
    instance_type = "ml.m5.large", #Tipo de servidor de entrenamiento
    predictor_type = "classifier", #Tipo de predicción del algoritmo
    sagemaker_session = sesion, #Sesión de SageMaker
    base_job_name = "entrenamiento-prediccion-categorica", #Nombre del job de entrenamiento
    num_classes = 4 #Número de categorías en el label
)
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %%
#Configuramos los parametros del algoritmo
entrenador.set_hyperparameters(
    feature_dim = 12, #Cantidad de features
    predictor_type = "classifier", #Indicamos que tipo de predicción es
    normalize_data = "true", #Normalizamos los features
    normalize_label = "false", #NO Normalizamos el label
    num_round = 100, #Número de árboles generados
    max_depth = 7, #Profundidad máxima del arbol
    colsample_bytree = 0.95 #Porcentaje de registros validos para generalizar
)

# %% [markdown]
# # 4. Entrenamiento del Modelo

# %%
#Entrenamos y validamos el modelo
#MIENTRAS SE ENTRENA EL MODELO: En SageMaker, en la sección "Jobs", en la opción "Training" podemos ver cómo el modelo se entrena
#TIEMPO DE ENTRENAMIENTO: 5 MINUTOS
entrenador.fit({"train": dataTrain, "validation": dataTest})
# Out:
# INFO:sagemaker:Creating training-job with name: entrenamiento-prediccion-categorica-2024-09-30-22-10-07-106
# 2024-09-30 22:10:09 Starting - Starting the training job...
# 2024-09-30 22:10:24 Starting - Preparing the instances for training...
# 2024-09-30 22:10:57 Downloading - Downloading input data......
# 2024-09-30 22:11:48 Downloading - Downloading the training image..Arguments: train
# [2024-09-30:22:12:27:INFO] Running standalone xgboost training.
# [2024-09-30:22:12:27:INFO] File size need to be processed in the node: 0.75mb. Available memory size in the node: 236.18mb
# [2024-09-30:22:12:27:INFO] Determined delimiter of CSV input is ','
# [22:12:27] S3DistributionType set as FullyReplicated
# [22:12:27] 10712x12 matrix with 128544 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2024-09-30:22:12:27:INFO] Determined delimiter of CSV input is ','
# [22:12:27] S3DistributionType set as FullyReplicated
# [22:12:27] 2678x12 matrix with 32136 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [22:12:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [0]#011train-rmse:1.17015#011validation-rmse:1.16206
# [22:12:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [1]#011train-rmse:0.944618#011validation-rmse:0.947334
# [22:12:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [2]#011train-rmse:0.781167#011validation-rmse:0.791142
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=7
# [3]#011train-rmse:0.673205#011validation-rmse:0.689778
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=7
# [4]#011train-rmse:0.607638#011validation-rmse:0.631754
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 0 pruned nodes, max_depth=7
# [5]#011train-rmse:0.570967#011validation-rmse:0.602996
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=7
# [6]#011train-rmse:0.539105#011validation-rmse:0.578799
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 0 pruned nodes, max_depth=7
# [7]#011train-rmse:0.51936#011validation-rmse:0.568516
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 0 pruned nodes, max_depth=7
# [8]#011train-rmse:0.505349#011validation-rmse:0.56268
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [9]#011train-rmse:0.495219#011validation-rmse:0.557979
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 0 pruned nodes, max_depth=7
# [10]#011train-rmse:0.486986#011validation-rmse:0.556326
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [11]#011train-rmse:0.478726#011validation-rmse:0.554655
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [12]#011train-rmse:0.472368#011validation-rmse:0.553295
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=7
# [13]#011train-rmse:0.4666#011validation-rmse:0.552152
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 0 pruned nodes, max_depth=7
# [14]#011train-rmse:0.458559#011validation-rmse:0.554291
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [15]#011train-rmse:0.45483#011validation-rmse:0.554428
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [16]#011train-rmse:0.449714#011validation-rmse:0.555356
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [17]#011train-rmse:0.448162#011validation-rmse:0.55534
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=7
# [18]#011train-rmse:0.443483#011validation-rmse:0.554777
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [19]#011train-rmse:0.439205#011validation-rmse:0.555443
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 0 pruned nodes, max_depth=7
# [20]#011train-rmse:0.432646#011validation-rmse:0.555003
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 0 pruned nodes, max_depth=7
# [21]#011train-rmse:0.428945#011validation-rmse:0.555558
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 0 pruned nodes, max_depth=7
# [22]#011train-rmse:0.424658#011validation-rmse:0.555666
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [23]#011train-rmse:0.4218#011validation-rmse:0.555352
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [24]#011train-rmse:0.418593#011validation-rmse:0.555767
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [25]#011train-rmse:0.414858#011validation-rmse:0.555354
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [26]#011train-rmse:0.411615#011validation-rmse:0.555747
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [27]#011train-rmse:0.408739#011validation-rmse:0.555809
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=7
# [28]#011train-rmse:0.407729#011validation-rmse:0.556279
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=7
# [29]#011train-rmse:0.406121#011validation-rmse:0.556129
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 0 pruned nodes, max_depth=7
# [30]#011train-rmse:0.402146#011validation-rmse:0.556665
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 0 pruned nodes, max_depth=7
# [31]#011train-rmse:0.396416#011validation-rmse:0.556253
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=7
# [32]#011train-rmse:0.391258#011validation-rmse:0.556263
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [33]#011train-rmse:0.38935#011validation-rmse:0.556389
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 0 pruned nodes, max_depth=7
# [34]#011train-rmse:0.387016#011validation-rmse:0.556267
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=7
# [35]#011train-rmse:0.385502#011validation-rmse:0.556488
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [36]#011train-rmse:0.381956#011validation-rmse:0.557142
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 0 pruned nodes, max_depth=7
# [37]#011train-rmse:0.378858#011validation-rmse:0.55748
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 0 pruned nodes, max_depth=7
# [38]#011train-rmse:0.376785#011validation-rmse:0.557252
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [39]#011train-rmse:0.374891#011validation-rmse:0.557597
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 0 pruned nodes, max_depth=7
# [40]#011train-rmse:0.370543#011validation-rmse:0.558147
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [41]#011train-rmse:0.369564#011validation-rmse:0.558242
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [42]#011train-rmse:0.368631#011validation-rmse:0.558688
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=7
# [43]#011train-rmse:0.366354#011validation-rmse:0.559517
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [44]#011train-rmse:0.365388#011validation-rmse:0.559541
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [45]#011train-rmse:0.36364#011validation-rmse:0.560484
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [46]#011train-rmse:0.360339#011validation-rmse:0.56018
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [47]#011train-rmse:0.358387#011validation-rmse:0.560569
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [48]#011train-rmse:0.355382#011validation-rmse:0.561112
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=7
# [49]#011train-rmse:0.353322#011validation-rmse:0.561362
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [50]#011train-rmse:0.352288#011validation-rmse:0.561678
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=7
# [51]#011train-rmse:0.351726#011validation-rmse:0.561999
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [52]#011train-rmse:0.349402#011validation-rmse:0.562619
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [53]#011train-rmse:0.348647#011validation-rmse:0.56338
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=7
# [54]#011train-rmse:0.345143#011validation-rmse:0.563296
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=7
# [55]#011train-rmse:0.342602#011validation-rmse:0.563371
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 0 pruned nodes, max_depth=7
# [56]#011train-rmse:0.338924#011validation-rmse:0.563944
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [57]#011train-rmse:0.338356#011validation-rmse:0.563775
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [58]#011train-rmse:0.335174#011validation-rmse:0.563839
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [59]#011train-rmse:0.333204#011validation-rmse:0.564193
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 0 pruned nodes, max_depth=7
# [60]#011train-rmse:0.330268#011validation-rmse:0.564382
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 0 pruned nodes, max_depth=7
# [61]#011train-rmse:0.32698#011validation-rmse:0.564638
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [62]#011train-rmse:0.325944#011validation-rmse:0.564658
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [63]#011train-rmse:0.325129#011validation-rmse:0.564717
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 0 pruned nodes, max_depth=7
# [64]#011train-rmse:0.32358#011validation-rmse:0.564679
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 0 pruned nodes, max_depth=7
# [65]#011train-rmse:0.319696#011validation-rmse:0.564854
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [66]#011train-rmse:0.319193#011validation-rmse:0.565087
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 0 pruned nodes, max_depth=7
# [67]#011train-rmse:0.316076#011validation-rmse:0.564366
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [68]#011train-rmse:0.315207#011validation-rmse:0.564265
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=7
# [69]#011train-rmse:0.314735#011validation-rmse:0.564007
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 0 pruned nodes, max_depth=7
# [70]#011train-rmse:0.310871#011validation-rmse:0.564329
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=7
# [71]#011train-rmse:0.307134#011validation-rmse:0.564863
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 0 pruned nodes, max_depth=7
# [72]#011train-rmse:0.303893#011validation-rmse:0.565263
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [73]#011train-rmse:0.302247#011validation-rmse:0.565615
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [74]#011train-rmse:0.299993#011validation-rmse:0.566439
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 0 pruned nodes, max_depth=7
# [75]#011train-rmse:0.296586#011validation-rmse:0.566384
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [76]#011train-rmse:0.296155#011validation-rmse:0.56645
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 0 pruned nodes, max_depth=7
# [77]#011train-rmse:0.294678#011validation-rmse:0.566754
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [78]#011train-rmse:0.292476#011validation-rmse:0.566882
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [79]#011train-rmse:0.290554#011validation-rmse:0.566981
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [80]#011train-rmse:0.289862#011validation-rmse:0.566948
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [81]#011train-rmse:0.289614#011validation-rmse:0.567126
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 0 pruned nodes, max_depth=7
# [82]#011train-rmse:0.286762#011validation-rmse:0.567127
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 0 pruned nodes, max_depth=7
# [83]#011train-rmse:0.283982#011validation-rmse:0.567073
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=7
# [84]#011train-rmse:0.281448#011validation-rmse:0.567485
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [85]#011train-rmse:0.280506#011validation-rmse:0.567754
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [86]#011train-rmse:0.279398#011validation-rmse:0.567627
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 0 pruned nodes, max_depth=7
# [87]#011train-rmse:0.275174#011validation-rmse:0.568236
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 0 pruned nodes, max_depth=7
# [88]#011train-rmse:0.273007#011validation-rmse:0.568565
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [89]#011train-rmse:0.271362#011validation-rmse:0.56848
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=7
# [90]#011train-rmse:0.268629#011validation-rmse:0.569152
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 0 pruned nodes, max_depth=7
# [91]#011train-rmse:0.267385#011validation-rmse:0.569297
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [92]#011train-rmse:0.267203#011validation-rmse:0.569379
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 0 pruned nodes, max_depth=7
# [93]#011train-rmse:0.265372#011validation-rmse:0.569347
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 0 pruned nodes, max_depth=7
# [94]#011train-rmse:0.263134#011validation-rmse:0.569214
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 0 pruned nodes, max_depth=7
# [95]#011train-rmse:0.260655#011validation-rmse:0.570023
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [96]#011train-rmse:0.259598#011validation-rmse:0.570171
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 0 pruned nodes, max_depth=7
# [97]#011train-rmse:0.258018#011validation-rmse:0.569873
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 0 pruned nodes, max_depth=7
# [98]#011train-rmse:0.255428#011validation-rmse:0.570053
# [22:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 0 pruned nodes, max_depth=7
# [99]#011train-rmse:0.25198#011validation-rmse:0.56948
#
# 2024-09-30 22:12:34 Training - Training image download completed. Training in progress.
# 2024-09-30 22:12:34 Uploading - Uploading generated training model
# 2024-09-30 22:12:48 Completed - Training job completed
# Training seconds: 110
# Billable seconds: 110

# %% [markdown]
# # 5. ESTADISTICAS DEL MODELO

# %%
#Librería para manipular los servicios de AWS
import boto3

#Nos conectamos al servicio de SageMaker
sagemakerCliente = boto3.client("sagemaker")

#Obtenemos el nombre del último entrenamiento realizado
nombreDeEntrenamiento = entrenador.latest_training_job.name

#Verificamos
print(nombreDeEntrenamiento)

#Obtenemos la descripción del entrenamiento
descripcionDeEntrenamiento = sagemakerCliente.describe_training_job(TrainingJobName = nombreDeEntrenamiento)

#Vemos toda la descripción de entrenamiento
descripcionDeEntrenamiento

#Dentro de la sub-variable "FinalMetricDataList" tenemos las métricas del modelo
#El error cuadrático medio se encuentra en "validation:mse"
#El r2 (error "porcentual") se encuentra en "validation:r2"
#IMPORTANTE: En SageMaker, en la sección "Jobs", en la opción "Training" podemos ver las estadísticas del modelo
descripcionDeEntrenamiento["FinalMetricDataList"]
# Out:
# entrenamiento-prediccion-categorica-2024-09-30-22-10-07-106
# [{'MetricName': 'train:rmse',
#   'Value': 0.2519800066947937,
#   'Timestamp': datetime.datetime(2024, 9, 30, 22, 12, 29, tzinfo=tzlocal())},
#  {'MetricName': 'validation:rmse',
#   'Value': 0.5694800019264221,
#   'Timestamp': datetime.datetime(2024, 9, 30, 22, 12, 29, tzinfo=tzlocal())}]
