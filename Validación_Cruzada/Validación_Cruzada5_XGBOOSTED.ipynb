# %% [markdown]
# # 1. Inicio de Sesión sobre SageMaker

# %%
#Utilitario para construir modelos de Machine Learning y Deep Learning
import sagemaker

#Importamos el utilitario para definir el entrenador del algoritmo
from sagemaker.estimator import Estimator

#Librería para manipular los servicios de AWS
import boto3

#Iniciamos sesión en el servicio de SageMaker
sesion = sagemaker.Session()

#Obtenemos la ejecución en donde estamos trabajando
region = sesion.boto_region_name

#Verificamos
print(region)

#Obtenemos el rol de ejecución de SageMaker
#El rol de ejecución permite a SageMaker usar otros servicios de AWS
rol = sagemaker.get_execution_role()
# Out:
# us-east-1

# %% [markdown]
# # 2. Lectura de archivos

# %%
#Utilitario para leer archivos de datos
from sagemaker.inputs import TrainingInput

#Bucket en donde se encuentran los archivos
#IMPORTANTE: REEMPLAZAR "XXX" POR TUS INICIALES
bucket = "datasetsbdajac"

#Lectura de datos de entrenamiento
dataTrain = TrainingInput(
    f"s3://{bucket}/data/bodyperformance_dataset_validacion_cruzada/vc5/train", #Ruta del archivo
    content_type = "text/csv", #Formato del archivo
    distribution = "FullyReplicated", #El archivo será copiado en todos los servidores
    s3_data_type = "S3Prefix", #Desde donde se lee el archivo (S3)
    input_mode = "File", #Los registros se encuentran dentro de archivos
    record_wrapping = "None" #Envoltorio de optimización
)

#Lectura de datos de validación
dataTest = TrainingInput(
    f"s3://{bucket}/data/bodyperformance_dataset_validacion_cruzada/vc5/test", #Ruta del archivo
    content_type = "text/csv", #Formato del archivo
    distribution = "FullyReplicated", #El archivo será copiado en todos los servidores
    s3_data_type = "S3Prefix", #Desde donde se lee el archivo (S3)
    input_mode = "File", #Los registros se encuentran dentro de archivos
    record_wrapping = "None" #Envoltorio de optimización
)

# %% [markdown]
# # 3. Configuración del Algoritmo

# %%
#Importamos el utilitario para definir el entrenador del algoritmo
from sagemaker.estimator import Estimator

#Definimos el entrenador del algoritmo
entrenador = Estimator(
    image_uri = sagemaker.image_uris.retrieve("xgboost", region, version = "latest"), #Descargamos la implementación del algoritmo desde la región donde trabajamos
    role = rol, #Rol que ejecuta servicios sobre AWS
    instance_count = 1, #Cantidad de servidores de entrenamiento
    instance_type = "ml.m5.large", #Tipo de servidor de entrenamiento
    predictor_type = "classifier", #Tipo de predicción del algoritmo
    sagemaker_session = sesion, #Sesión de SageMaker
    base_job_name = "entrenamiento-prediccion-categorica", #Nombre del job de entrenamiento
    num_classes = 4 #Número de categorías en el label
)
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %%
#Configuramos los parametros del algoritmo
entrenador.set_hyperparameters(
    feature_dim = 12, #Cantidad de features
    predictor_type = "classifier", #Indicamos que tipo de predicción es
    normalize_data = "true", #Normalizamos los features
    normalize_label = "false", #NO Normalizamos el label
    num_round = 100, #Número de árboles generados
    max_depth = 7, #Profundidad máxima del arbol
    colsample_bytree = 0.95 #Porcentaje de registros validos para generalizar
)

# %% [markdown]
# # 4. Entrenamiento del Modelo

# %%
#Entrenamos y validamos el modelo
#MIENTRAS SE ENTRENA EL MODELO: En SageMaker, en la sección "Jobs", en la opción "Training" podemos ver cómo el modelo se entrena
#TIEMPO DE ENTRENAMIENTO: 5 MINUTOS
entrenador.fit({"train": dataTrain, "validation": dataTest})
# Out:
# INFO:sagemaker:Creating training-job with name: entrenamiento-prediccion-categorica-2024-09-30-22-19-06-716
# 2024-09-30 22:19:08 Starting - Starting the training job...
# 2024-09-30 22:19:23 Starting - Preparing the instances for training...
# 2024-09-30 22:19:54 Downloading - Downloading input data...
# 2024-09-30 22:20:39 Downloading - Downloading the training image.....Arguments: train
# [2024-09-30:22:21:19:INFO] Running standalone xgboost training.
# [2024-09-30:22:21:19:INFO] File size need to be processed in the node: 0.75mb. Available memory size in the node: 238.79mb
# [2024-09-30:22:21:19:INFO] Determined delimiter of CSV input is ','
# [22:21:19] S3DistributionType set as FullyReplicated
# [22:21:19] 10711x12 matrix with 128532 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2024-09-30:22:21:19:INFO] Determined delimiter of CSV input is ','
# [22:21:19] S3DistributionType set as FullyReplicated
# [22:21:19] 2679x12 matrix with 32148 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 0 pruned nodes, max_depth=7
# [0]#011train-rmse:1.16436#011validation-rmse:1.18216
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 0 pruned nodes, max_depth=7
# [1]#011train-rmse:0.936366#011validation-rmse:0.962102
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [2]#011train-rmse:0.774446#011validation-rmse:0.806963
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 0 pruned nodes, max_depth=7
# [3]#011train-rmse:0.666833#011validation-rmse:0.709132
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=7
# [4]#011train-rmse:0.600985#011validation-rmse:0.651494
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 0 pruned nodes, max_depth=7
# [5]#011train-rmse:0.563926#011validation-rmse:0.623397
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 0 pruned nodes, max_depth=7
# [6]#011train-rmse:0.535494#011validation-rmse:0.60135
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 0 pruned nodes, max_depth=7
# [7]#011train-rmse:0.516277#011validation-rmse:0.590728
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 0 pruned nodes, max_depth=7
# [8]#011train-rmse:0.502179#011validation-rmse:0.585792
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 0 pruned nodes, max_depth=7
# [9]#011train-rmse:0.490889#011validation-rmse:0.581134
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 0 pruned nodes, max_depth=7
# [10]#011train-rmse:0.483298#011validation-rmse:0.577624
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [11]#011train-rmse:0.475402#011validation-rmse:0.574413
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 0 pruned nodes, max_depth=7
# [12]#011train-rmse:0.467123#011validation-rmse:0.574325
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [13]#011train-rmse:0.461575#011validation-rmse:0.573523
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=7
# [14]#011train-rmse:0.459504#011validation-rmse:0.573733
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [15]#011train-rmse:0.455652#011validation-rmse:0.573513
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 0 pruned nodes, max_depth=7
# [16]#011train-rmse:0.450294#011validation-rmse:0.57311
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [17]#011train-rmse:0.449473#011validation-rmse:0.573093
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 0 pruned nodes, max_depth=7
# [18]#011train-rmse:0.445003#011validation-rmse:0.572858
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 0 pruned nodes, max_depth=7
# [19]#011train-rmse:0.437553#011validation-rmse:0.572474
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 0 pruned nodes, max_depth=7
# [20]#011train-rmse:0.43222#011validation-rmse:0.573925
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [21]#011train-rmse:0.42856#011validation-rmse:0.574497
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 0 pruned nodes, max_depth=7
# [22]#011train-rmse:0.425015#011validation-rmse:0.57467
# [22:21:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
#
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 0 pruned nodes, max_depth=7
# [68]#011train-rmse:0.312866#011validation-rmse:0.583689
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 0 pruned nodes, max_depth=7
# [69]#011train-rmse:0.309097#011validation-rmse:0.583665
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [70]#011train-rmse:0.307957#011validation-rmse:0.58373
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 0 pruned nodes, max_depth=7
# [71]#011train-rmse:0.306299#011validation-rmse:0.583953
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=7
# [72]#011train-rmse:0.305132#011validation-rmse:0.583636
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [73]#011train-rmse:0.302951#011validation-rmse:0.583465
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [74]#011train-rmse:0.300676#011validation-rmse:0.583336
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [75]#011train-rmse:0.299615#011validation-rmse:0.583533
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 0 pruned nodes, max_depth=7
# [76]#011train-rmse:0.296163#011validation-rmse:0.584186
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=7
# [77]#011train-rmse:0.295275#011validation-rmse:0.584294
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 0 pruned nodes, max_depth=7
# [78]#011train-rmse:0.292647#011validation-rmse:0.58487
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 0 pruned nodes, max_depth=7
# [79]#011train-rmse:0.290765#011validation-rmse:0.584796
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [80]#011train-rmse:0.290085#011validation-rmse:0.584879
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=7
# [81]#011train-rmse:0.288881#011validation-rmse:0.584855
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 0 pruned nodes, max_depth=7
# [82]#011train-rmse:0.285329#011validation-rmse:0.5856
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 0 pruned nodes, max_depth=7
# [83]#011train-rmse:0.281131#011validation-rmse:0.586
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [84]#011train-rmse:0.27998#011validation-rmse:0.58588
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 0 pruned nodes, max_depth=7
# [85]#011train-rmse:0.277214#011validation-rmse:0.585746
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [86]#011train-rmse:0.276296#011validation-rmse:0.585871
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 0 pruned nodes, max_depth=7
# [87]#011train-rmse:0.272356#011validation-rmse:0.586369
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=7
# [88]#011train-rmse:0.272024#011validation-rmse:0.586439
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 0 pruned nodes, max_depth=7
# [89]#011train-rmse:0.269691#011validation-rmse:0.586155
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 0 pruned nodes, max_depth=7
# [90]#011train-rmse:0.266636#011validation-rmse:0.586529
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 0 pruned nodes, max_depth=7
# [91]#011train-rmse:0.263385#011validation-rmse:0.587404
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [92]#011train-rmse:0.26222#011validation-rmse:0.587243
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [93]#011train-rmse:0.260649#011validation-rmse:0.587523
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [94]#011train-rmse:0.259959#011validation-rmse:0.587648
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [95]#011train-rmse:0.259818#011validation-rmse:0.587686
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [96]#011train-rmse:0.259603#011validation-rmse:0.587716
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 0 pruned nodes, max_depth=7
# [97]#011train-rmse:0.256931#011validation-rmse:0.587992
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [98]#011train-rmse:0.255692#011validation-rmse:0.587992
# [22:21:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=7
# [99]#011train-rmse:0.255407#011validation-rmse:0.58792
#
# 2024-09-30 22:21:39 Training - Training image download completed. Training in progress.
# 2024-09-30 22:21:39 Uploading - Uploading generated training model
# 2024-09-30 22:21:39 Completed - Training job completed
# Training seconds: 105
# Billable seconds: 105

# %% [markdown]
# # 5. ESTADISTICAS DEL MODELO

# %%
#Librería para manipular los servicios de AWS
import boto3

#Nos conectamos al servicio de SageMaker
sagemakerCliente = boto3.client("sagemaker")

#Obtenemos el nombre del último entrenamiento realizado
nombreDeEntrenamiento = entrenador.latest_training_job.name

#Verificamos
print(nombreDeEntrenamiento)

#Obtenemos la descripción del entrenamiento
descripcionDeEntrenamiento = sagemakerCliente.describe_training_job(TrainingJobName = nombreDeEntrenamiento)

#Vemos toda la descripción de entrenamiento
descripcionDeEntrenamiento

#Dentro de la sub-variable "FinalMetricDataList" tenemos las métricas del modelo
#El error cuadrático medio se encuentra en "validation:mse"
#El r2 (error "porcentual") se encuentra en "validation:r2"
#IMPORTANTE: En SageMaker, en la sección "Jobs", en la opción "Training" podemos ver las estadísticas del modelo
descripcionDeEntrenamiento["FinalMetricDataList"]
# Out:
# entrenamiento-prediccion-categorica-2024-09-30-22-19-06-716
# [{'MetricName': 'train:rmse',
#   'Value': 0.2554070055484772,
#   'Timestamp': datetime.datetime(2024, 9, 30, 22, 21, 20, tzinfo=tzlocal())},
#  {'MetricName': 'validation:rmse',
#   'Value': 0.5879200100898743,
#   'Timestamp': datetime.datetime(2024, 9, 30, 22, 21, 20, tzinfo=tzlocal())}]
