# %% [markdown]
# # 1. Inicio de Sesión sobre SageMaker

# %%
#Utilitario para construir modelos de Machine Learning y Deep Learning
import sagemaker

#Importamos el utilitario para definir el entrenador del algoritmo
from sagemaker.estimator import Estimator

#Librería para manipular los servicios de AWS
import boto3

#Iniciamos sesión en el servicio de SageMaker
sesion = sagemaker.Session()

#Obtenemos la ejecución en donde estamos trabajando
region = sesion.boto_region_name

#Verificamos
print(region)

#Obtenemos el rol de ejecución de SageMaker
#El rol de ejecución permite a SageMaker usar otros servicios de AWS
rol = sagemaker.get_execution_role()
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# us-east-1

# %% [markdown]
# # 2. Lectura de archivos

# %%
#Utilitario para leer archivos de datos
from sagemaker.inputs import TrainingInput

#Bucket en donde se encuentran los archivos
#IMPORTANTE: REEMPLAZAR "XXX" POR TUS INICIALES
bucket = "datasetsbdajac"

#Lectura de datos de entrenamiento
dataTrain = TrainingInput(
    f"s3://{bucket}/data/bodyperformance_dataset_validacion_cruzada/vc2/train", #Ruta del archivo
    content_type = "text/csv", #Formato del archivo
    distribution = "FullyReplicated", #El archivo será copiado en todos los servidores
    s3_data_type = "S3Prefix", #Desde donde se lee el archivo (S3)
    input_mode = "File", #Los registros se encuentran dentro de archivos
    record_wrapping = "None" #Envoltorio de optimización
)

#Lectura de datos de validación
dataTest = TrainingInput(
    f"s3://{bucket}/data/bodyperformance_dataset_validacion_cruzada/vc2/test", #Ruta del archivo
    content_type = "text/csv", #Formato del archivo
    distribution = "FullyReplicated", #El archivo será copiado en todos los servidores
    s3_data_type = "S3Prefix", #Desde donde se lee el archivo (S3)
    input_mode = "File", #Los registros se encuentran dentro de archivos
    record_wrapping = "None" #Envoltorio de optimización
)

# %% [markdown]
# # 3. Configuración del Algoritmo

# %%
#Importamos el utilitario para definir el entrenador del algoritmo
from sagemaker.estimator import Estimator

#Definimos el entrenador del algoritmo
entrenador = Estimator(
    image_uri = sagemaker.image_uris.retrieve("xgboost", region, version = "latest"), #Descargamos la implementación del algoritmo desde la región donde trabajamos
    role = rol, #Rol que ejecuta servicios sobre AWS
    instance_count = 1, #Cantidad de servidores de entrenamiento
    instance_type = "ml.m5.large", #Tipo de servidor de entrenamiento
    predictor_type = "classifier", #Tipo de predicción del algoritmo
    sagemaker_session = sesion, #Sesión de SageMaker
    base_job_name = "entrenamiento-prediccion-categorica", #Nombre del job de entrenamiento
    num_classes = 4 #Número de categorías en el label
)

# %%
#Configuramos los parametros del algoritmo
entrenador.set_hyperparameters(
    feature_dim = 12, #Cantidad de features
    predictor_type = "classifier", #Indicamos que tipo de predicción es
    normalize_data = "true", #Normalizamos los features
    normalize_label = "false", #NO Normalizamos el label
    num_round = 100, #Número de árboles generados
    max_depth = 7, #Profundidad máxima del arbol
    colsample_bytree = 0.95 #Porcentaje de registros validos para generalizar
)

# %% [markdown]
# # 4. Entrenamiento del Modelo

# %%
#Entrenamos y validamos el modelo
#MIENTRAS SE ENTRENA EL MODELO: En SageMaker, en la sección "Jobs", en la opción "Training" podemos ver cómo el modelo se entrena
#TIEMPO DE ENTRENAMIENTO: 5 MINUTOS
entrenador.fit({"train": dataTrain, "validation": dataTest})
# Out:
# INFO:sagemaker:Creating training-job with name: entrenamiento-prediccion-categorica-2024-09-30-22-03-18-480
# 2024-09-30 22:03:20 Starting - Starting the training job...
# 2024-09-30 22:03:34 Starting - Preparing the instances for training...
# 2024-09-30 22:04:11 Downloading - Downloading input data......
# 2024-09-30 22:04:56 Downloading - Downloading the training image...
# 2024-09-30 22:05:47 Training - Training image download completed. Training in progress.
# 2024-09-30 22:05:47 Uploading - Uploading generated training modelArguments: train
# [2024-09-30:22:05:40:INFO] Running standalone xgboost training.
# [2024-09-30:22:05:40:INFO] File size need to be processed in the node: 0.75mb. Available memory size in the node: 174.45mb
# [2024-09-30:22:05:40:INFO] Determined delimiter of CSV input is ','
# [22:05:40] S3DistributionType set as FullyReplicated
# [22:05:40] 10712x12 matrix with 128544 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2024-09-30:22:05:40:INFO] Determined delimiter of CSV input is ','
# [22:05:40] S3DistributionType set as FullyReplicated
# [22:05:40] 2678x12 matrix with 32136 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [0]#011train-rmse:1.16822#011validation-rmse:1.1727
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 0 pruned nodes, max_depth=7
# [1]#011train-rmse:0.942069#011validation-rmse:0.956288
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 0 pruned nodes, max_depth=7
# [2]#011train-rmse:0.773395#011validation-rmse:0.797463
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 0 pruned nodes, max_depth=7
# [3]#011train-rmse:0.671799#011validation-rmse:0.704685
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 0 pruned nodes, max_depth=7
# [4]#011train-rmse:0.603686#011validation-rmse:0.647524
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 0 pruned nodes, max_depth=7
# [5]#011train-rmse:0.565124#011validation-rmse:0.617363
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 0 pruned nodes, max_depth=7
# [6]#011train-rmse:0.53484#011validation-rmse:0.596317
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [7]#011train-rmse:0.515932#011validation-rmse:0.586333
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 0 pruned nodes, max_depth=7
# [8]#011train-rmse:0.501646#011validation-rmse:0.579436
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [9]#011train-rmse:0.489965#011validation-rmse:0.573244
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [10]#011train-rmse:0.483276#011validation-rmse:0.570226
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 0 pruned nodes, max_depth=7
# [11]#011train-rmse:0.473406#011validation-rmse:0.566827
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 0 pruned nodes, max_depth=7
# [12]#011train-rmse:0.467798#011validation-rmse:0.564751
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [13]#011train-rmse:0.463221#011validation-rmse:0.565229
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=7
# [14]#011train-rmse:0.462287#011validation-rmse:0.565381
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=7
# [15]#011train-rmse:0.460175#011validation-rmse:0.565299
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=7
# [16]#011train-rmse:0.456118#011validation-rmse:0.56517
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=7
# [17]#011train-rmse:0.452971#011validation-rmse:0.565912
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [18]#011train-rmse:0.448582#011validation-rmse:0.565784
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=7
# [19]#011train-rmse:0.446932#011validation-rmse:0.565651
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=7
# [20]#011train-rmse:0.445628#011validation-rmse:0.565638
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=7
# [21]#011train-rmse:0.442858#011validation-rmse:0.565367
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 0 pruned nodes, max_depth=7
# [22]#011train-rmse:0.43914#011validation-rmse:0.565865
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 0 pruned nodes, max_depth=7
# [23]#011train-rmse:0.43706#011validation-rmse:0.566622
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [24]#011train-rmse:0.436405#011validation-rmse:0.567171
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 0 pruned nodes, max_depth=7
# [25]#011train-rmse:0.433051#011validation-rmse:0.567964
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [26]#011train-rmse:0.429059#011validation-rmse:0.568932
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [27]#011train-rmse:0.427862#011validation-rmse:0.568769
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=7
# [28]#011train-rmse:0.427006#011validation-rmse:0.56833
# [22:05:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [29]#011train-rmse:0.424332#011validation-rmse:0.56839
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [30]#011train-rmse:0.423387#011validation-rmse:0.568321
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 0 pruned nodes, max_depth=7
# [31]#011train-rmse:0.419834#011validation-rmse:0.568565
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=7
# [32]#011train-rmse:0.41544#011validation-rmse:0.569377
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=7
# [33]#011train-rmse:0.414822#011validation-rmse:0.569608
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [34]#011train-rmse:0.414323#011validation-rmse:0.569519
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=7
# [35]#011train-rmse:0.408746#011validation-rmse:0.569817
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [36]#011train-rmse:0.405097#011validation-rmse:0.570948
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [37]#011train-rmse:0.404125#011validation-rmse:0.571027
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [38]#011train-rmse:0.402454#011validation-rmse:0.571016
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [39]#011train-rmse:0.399518#011validation-rmse:0.571475
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 0 pruned nodes, max_depth=7
# [40]#011train-rmse:0.394319#011validation-rmse:0.571013
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [41]#011train-rmse:0.39392#011validation-rmse:0.571037
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 0 pruned nodes, max_depth=7
# [42]#011train-rmse:0.392508#011validation-rmse:0.570905
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 0 pruned nodes, max_depth=7
# [43]#011train-rmse:0.388972#011validation-rmse:0.570634
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 0 pruned nodes, max_depth=7
# [44]#011train-rmse:0.384762#011validation-rmse:0.571431
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=7
# [45]#011train-rmse:0.38162#011validation-rmse:0.571213
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 0 pruned nodes, max_depth=7
# [46]#011train-rmse:0.375396#011validation-rmse:0.571626
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 0 pruned nodes, max_depth=7
# [47]#011train-rmse:0.371993#011validation-rmse:0.572121
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [48]#011train-rmse:0.370624#011validation-rmse:0.572523
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [49]#011train-rmse:0.36976#011validation-rmse:0.57304
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 0 pruned nodes, max_depth=7
# [50]#011train-rmse:0.365133#011validation-rmse:0.574144
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 0 pruned nodes, max_depth=7
# [51]#011train-rmse:0.360067#011validation-rmse:0.574893
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 0 pruned nodes, max_depth=7
# [52]#011train-rmse:0.356729#011validation-rmse:0.575478
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [53]#011train-rmse:0.355916#011validation-rmse:0.575551
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=7
# [54]#011train-rmse:0.352372#011validation-rmse:0.575702
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 0 pruned nodes, max_depth=7
# [55]#011train-rmse:0.349132#011validation-rmse:0.575257
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 0 pruned nodes, max_depth=7
# [56]#011train-rmse:0.348405#011validation-rmse:0.575279
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 0 pruned nodes, max_depth=7
# [57]#011train-rmse:0.345023#011validation-rmse:0.575287
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=7
# [58]#011train-rmse:0.344396#011validation-rmse:0.575242
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=7
# [59]#011train-rmse:0.343211#011validation-rmse:0.575555
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 0 pruned nodes, max_depth=7
# [60]#011train-rmse:0.339798#011validation-rmse:0.576373
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 0 pruned nodes, max_depth=7
# [61]#011train-rmse:0.33632#011validation-rmse:0.576204
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 0 pruned nodes, max_depth=7
# [62]#011train-rmse:0.33175#011validation-rmse:0.576464
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [63]#011train-rmse:0.330945#011validation-rmse:0.576522
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=7
# [64]#011train-rmse:0.329921#011validation-rmse:0.576782
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=7
# [65]#011train-rmse:0.329573#011validation-rmse:0.576721
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=7
# [66]#011train-rmse:0.327621#011validation-rmse:0.576912
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 0 pruned nodes, max_depth=7
# [67]#011train-rmse:0.324494#011validation-rmse:0.577154
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [68]#011train-rmse:0.322877#011validation-rmse:0.577604
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 0 pruned nodes, max_depth=7
# [69]#011train-rmse:0.320376#011validation-rmse:0.578248
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [70]#011train-rmse:0.319171#011validation-rmse:0.578789
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 0 pruned nodes, max_depth=7
# [71]#011train-rmse:0.316232#011validation-rmse:0.579796
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 0 pruned nodes, max_depth=7
# [72]#011train-rmse:0.312074#011validation-rmse:0.580887
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=7
# [73]#011train-rmse:0.310544#011validation-rmse:0.580623
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 0 pruned nodes, max_depth=7
# [74]#011train-rmse:0.307952#011validation-rmse:0.581241
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 0 pruned nodes, max_depth=7
# [75]#011train-rmse:0.305453#011validation-rmse:0.581413
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 0 pruned nodes, max_depth=7
# [76]#011train-rmse:0.302355#011validation-rmse:0.581131
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 0 pruned nodes, max_depth=7
# [77]#011train-rmse:0.300475#011validation-rmse:0.581582
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [78]#011train-rmse:0.29788#011validation-rmse:0.581354
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=7
# [79]#011train-rmse:0.296659#011validation-rmse:0.581661
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 0 pruned nodes, max_depth=7
# [80]#011train-rmse:0.292812#011validation-rmse:0.582191
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 0 pruned nodes, max_depth=7
# [81]#011train-rmse:0.290092#011validation-rmse:0.582316
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=7
# [82]#011train-rmse:0.28743#011validation-rmse:0.582375
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [83]#011train-rmse:0.285422#011validation-rmse:0.582496
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 0 pruned nodes, max_depth=7
# [84]#011train-rmse:0.283203#011validation-rmse:0.582437
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=7
# [85]#011train-rmse:0.281686#011validation-rmse:0.582477
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 0 pruned nodes, max_depth=7
# [86]#011train-rmse:0.2787#011validation-rmse:0.582887
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 0 pruned nodes, max_depth=7
# [87]#011train-rmse:0.276377#011validation-rmse:0.582956
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=7
# [88]#011train-rmse:0.275822#011validation-rmse:0.583133
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 0 pruned nodes, max_depth=7
# [89]#011train-rmse:0.27298#011validation-rmse:0.583303
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 0 pruned nodes, max_depth=7
# [90]#011train-rmse:0.271444#011validation-rmse:0.583471
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 0 pruned nodes, max_depth=7
# [91]#011train-rmse:0.270569#011validation-rmse:0.583845
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=7
# [92]#011train-rmse:0.269328#011validation-rmse:0.5837
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 0 pruned nodes, max_depth=7
# [93]#011train-rmse:0.266977#011validation-rmse:0.583757
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 0 pruned nodes, max_depth=7
# [94]#011train-rmse:0.265235#011validation-rmse:0.584026
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=7
# [95]#011train-rmse:0.263365#011validation-rmse:0.583706
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [96]#011train-rmse:0.262891#011validation-rmse:0.583671
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=7
# [97]#011train-rmse:0.262643#011validation-rmse:0.583851
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 0 pruned nodes, max_depth=7
# [98]#011train-rmse:0.259469#011validation-rmse:0.58388
# [22:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=7
# [99]#011train-rmse:0.257168#011validation-rmse:0.583756
#
# 2024-09-30 22:06:01 Completed - Training job completed
# Training seconds: 110
# Billable seconds: 110

# %% [markdown]
# # 5. ESTADISTICAS DEL MODELO

# %%
#Librería para manipular los servicios de AWS
import boto3

#Nos conectamos al servicio de SageMaker
sagemakerCliente = boto3.client("sagemaker")

#Obtenemos el nombre del último entrenamiento realizado
nombreDeEntrenamiento = entrenador.latest_training_job.name

#Verificamos
print(nombreDeEntrenamiento)

#Obtenemos la descripción del entrenamiento
descripcionDeEntrenamiento = sagemakerCliente.describe_training_job(TrainingJobName = nombreDeEntrenamiento)

#Vemos toda la descripción de entrenamiento
descripcionDeEntrenamiento

#Dentro de la sub-variable "FinalMetricDataList" tenemos las métricas del modelo
#El error cuadrático medio se encuentra en "validation:mse"
#El r2 (error "porcentual") se encuentra en "validation:r2"
#IMPORTANTE: En SageMaker, en la sección "Jobs", en la opción "Training" podemos ver las estadísticas del modelo
descripcionDeEntrenamiento["FinalMetricDataList"]
# Out:
# entrenamiento-prediccion-categorica-2024-09-30-22-03-18-480
# [{'MetricName': 'train:rmse',
#   'Value': 0.2571679949760437,
#   'Timestamp': datetime.datetime(2024, 9, 30, 22, 5, 41, tzinfo=tzlocal())},
#  {'MetricName': 'validation:rmse',
#   'Value': 0.5837560296058655,
#   'Timestamp': datetime.datetime(2024, 9, 30, 22, 5, 41, tzinfo=tzlocal())}]
